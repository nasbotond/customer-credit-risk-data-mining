# %% [markdown]
# # Task Description
#
# The data set, related to customer credit risk, and the description of the attributes are uploaded in the Files.
#
# There are three tasks for the semestral project, such that
# 1) Develop a prediction model to classify the customers as good or bad
#
# 2) Cluster the customers into various groups
#
# 3) Provide some ideas on how frequent pattern mining could be utilized to uncover some patterns in the data and/or to enhance the classification

# %% [markdown]
# # Import data
# Import the dataset with Pandas pd.read_csv command. Data is seperated with semicolon, so seperation parameter has to be set.

# %%
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.model_selection import train_test_split
from apyori import apriori

dataset = pd.read_csv('../data/project_data.csv',sep=';')

# %% [markdown]
# # Data description
#
# Description of the attributes (columns) in the data and their values:
#
# Attribute X01: Status of existing checking account of the customer
# A11: X01 < 0 EUR
# A12: 0 <= X01 < 200 EUR
# A13: X01 >= 200 EUR
# A14: no checking account
#
# Attribute X02: Duration of the credit (requested by the customer from the bank) in month
#
# Attribute X03: Credit history of the customer
# A30: no credits taken or all credits paid back duly
# A31: all credits at this bank paid back duly
# A32: existing credits paid back duly till now
# A33: delay in paying off in the past
# A34: critical account or other credits existing (not at this bank)
#
# Attribute X04: Purpose of the credit
# A40: car (new)
# A41: car (used)
# A42: furniture/equipment
# A43: radio/television
# A44: domestic appliances
# A45: repairs
# A46: education
# A47: vacation
# A48: retraining
# A49: business
# A410: others
#
# Attribute X05: Credit amount in EUR
#
# Attibute X06: Savings account/bonds of the customer
# A61: X06 < 100 EUR
# A62: 100 <= X06 < 500 EUR
# A63: 500 <= X06 < 1000 EUR
# A64: X06 >= 1000 EUR
# A65: unknown/no savings account
#
# Attribute X07: Present employment of the customer since
# A71: unemployed
# A72: X07 < 1 year
# A73: 1 <= X07 < 4 years
# A74: 4 <= X07 < 7 years
# A75: X07 >= 7 years
#
# Attribute X08: Installment rate in percentage of disposable income
#
# Attribute X09: Personal status and sex of the customer
# A91: male - divorced/separated
# A92: female - divorced/separated/married
# A93: male - single
# A94: male - married/widowed
# A95: female - single
#
# Attribute X10: Other debtors or guarantors for the credit
# A101: none
# A102: co-applicant
# A103: guarantor
#
# Attribute X11: Present residence of the customer since (in years)
#
# Attribute X12: Property owned by the customer
# A121: real estate
# A122: if not A121 - building society savings agreement/life insurance
# A123: if not A121/A122 - car or other, not in attribute X06
# A124: unknown/no property
#
# Attribute X13: Age of the customer in years
#
# Attribute X14: Other installment plans of the customer
# A141: bank
# A142: stores
# A143: none
#
# Attribute X15: Housing situation of the customer
# A151: renting
# A152: owning
# A153: accommodation (ie. living) for free
#
# Attribute X16: Number of existing credits of the customer at this bank
#
# Attribute X17: Job situation of the customer
# A171: unemployed/unskilled  - non-resident
# A172: unskilled - resident
# A173: skilled employee/official
# A174: management/self-employed/highly qualified employee/officer
#
# Attribute X18: Number of people the customer being liable to provide maintenance for
#
# Attribute X19: Telephone of the customer (Note: the data are from 1994, having a phone was not usual back then)
# A191: none
# A192: yes, registered under the customers name
#
# Attribute X20: if the customer is a foreign worker
# A201: yes
# A202: no
#
# Attribute Y: label
# 1 = good customer, ie. paid back the requested credit (see the attributes X02, X04, X05)
# 2 = bad customer, ie. did not pay back the requested credit (see the attributes X02, X04, X05)
#
# Please, note, that it is five times worse to classify customers as good when they are bad than it is to classify customers bad when they are good!

# %% [markdown]
# Display first 5 rows of the data

# %%
dataset.head()
# Out:
#    X01  X02  X03  X04   X05  X06  X07  X08  X09   X10  ...   X12 X13   X14  \
# 0  A11    6  A34  A43  1169  A65  A75    4  A93  A101  ...  A121  67  A143
# 1  A12   48  A32  A43  5951  A61  A73    2  A92  A101  ...  A121  22  A143
# 2  A14   12  A34  A46  2096  A61  A74    2  A93  A101  ...  A121  49  A143
# 3  A11   42  A32  A42  7882  A61  A74    2  A93  A103  ...  A122  45  A143
# 4  A11   24  A33  A40  4870  A61  A73    3  A93  A101  ...  A124  53  A143
#
#     X15 X16   X17 X18   X19   X20  Y
# 0  A152   2  A173   1  A192  A201  1
# 1  A152   1  A173   1  A191  A201  2
# 2  A152   1  A172   2  A191  A201  1
# 3  A153   1  A173   2  A191  A201  1
# 4  A153   2  A173   2  A191  A201  2
#
# [5 rows x 21 columns]

# %%
# Any missing values?
dataset.isnull().values.any()
# Out:
# False

# %%
dataset.describe()
# Out:
#                X02           X05          X08          X11          X13  \
# count  1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean     20.903000   3271.258000     2.973000     2.845000    35.546000
# std      12.058814   2822.736876     1.118715     1.103718    11.375469
# min       4.000000    250.000000     1.000000     1.000000    19.000000
# 25%      12.000000   1365.500000     2.000000     2.000000    27.000000
# 50%      18.000000   2319.500000     3.000000     3.000000    33.000000
# 75%      24.000000   3972.250000     4.000000     4.000000    42.000000
# max      72.000000  18424.000000     4.000000     4.000000    75.000000
#
#                X16          X18            Y
# count  1000.000000  1000.000000  1000.000000
# mean      1.407000     1.155000     1.300000
# std       0.577654     0.362086     0.458487
# min       1.000000     1.000000     1.000000
# 25%       1.000000     1.000000     1.000000
# 50%       1.000000     1.000000     1.000000
# 75%       2.000000     1.000000     2.000000
# max       4.000000     2.000000     2.000000

# %% [markdown]
# # Task desciption
#
# There are three tasks for the semestral project, such that
#
# 1) Develop a prediction model to classify the customers as good or bad;
#
# 2) Cluster the customers into various groups;
#
# 3) Provide some ideas on how frequent pattern mining could be utilized to uncover some patterns in the data and/or to enhance the classification;

# %%
records = []
for i in range(0, 1000):
    records.append([str(dataset.values[i,j]) for j in range(0, 21)])

# %%
association_rules = apriori(records, min_support=0.05, min_confidence=0.6, min_lift=2, min_length=2, use_colnames=True)
association_results = list(association_rules)
print(association_results)
# Out:
# [RelationRecord(items=frozenset({'A153', 'A124'}), support=0.104, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A124'}), items_add=frozenset({'A153'}), confidence=0.6753246753246753, lift=6.253006253006253), OrderedStatistic(items_base=frozenset({'A153'}), items_add=frozenset({'A124'}), confidence=0.9629629629629629, lift=6.2530062530062525)]), RelationRecord(items=frozenset({'A192', 'A174'}), support=0.127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A174'}), items_add=frozenset({'A192'}), confidence=0.8581081081081081, lift=2.124029970564624)]), RelationRecord(items=frozenset({'A153', 'A124', '1'}), support=0.096, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A124'}), items_add=frozenset({'A153', '1'}), confidence=0.6233766233766234, lift=6.296733569460842), OrderedStatistic(items_base=frozenset({'A153'}), items_add=frozenset({'A124', '1'}), confidence=0.888888888888889, lift=6.216006216006217), OrderedStatistic(items_base=frozenset({'A124', '1'}), items_add=frozenset({'A153'}), confidence=0.6713286713286714, lift=6.216006216006217), OrderedStatistic(items_base=frozenset({'A153', '1'}), items_add=frozenset({'A124'}), confidence=0.9696969696969697, lift=6.296733569460843)]), RelationRecord(items=frozenset({'1', 'A192', 'A174'}), support=0.125, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A174'}), items_add=frozenset({'1', 'A192'}), confidence=0.8445945945945946, lift=2.1114864864864864), OrderedStatistic(items_base=frozenset({'1', 'A174'}), items_add=frozenset({'A192'}), confidence=0.8561643835616439, lift=2.119218771192188)]), RelationRecord(items=frozenset({'2', 'A153', 'A124'}), support=0.082, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A153'}), items_add=frozenset({'2', 'A124'}), confidence=0.7592592592592593, lift=6.123058542413381), OrderedStatistic(items_base=frozenset({'2', 'A124'}), items_add=frozenset({'A153'}), confidence=0.6612903225806452, lift=6.123058542413382), OrderedStatistic(items_base=frozenset({'2', 'A153'}), items_add=frozenset({'A124'}), confidence=0.9534883720930234, lift=6.191482935668983)]), RelationRecord(items=frozenset({'2', 'A192', 'A174'}), support=0.097, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A174'}), items_add=frozenset({'2', 'A192'}), confidence=0.6554054054054055, lift=2.087278361163712), OrderedStatistic(items_base=frozenset({'2', 'A174'}), items_add=frozenset({'A192'}), confidence=0.8362068965517241, lift=2.069819050870604)]), RelationRecord(items=frozenset({'A153', 'A124', '4'}), support=0.094, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A124'}), items_add=frozenset({'A153', '4'}), confidence=0.6103896103896104, lift=6.2926763957691785), OrderedStatistic(items_base=frozenset({'A153'}), items_add=frozenset({'A124', '4'}), confidence=0.8703703703703703, lift=6.695156695156695), OrderedStatistic(items_base=frozenset({'A124', '4'}), items_add=frozenset({'A153'}), confidence=0.7230769230769231, lift=6.695156695156695), OrderedStatistic(items_base=frozenset({'A153', '4'}), items_add=frozenset({'A124'}), confidence=0.9690721649484536, lift=6.292676395769179)]), RelationRecord(items=frozenset({'4', 'A192', 'A174'}), support=0.094, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A174'}), items_add=frozenset({'4', 'A192'}), confidence=0.6351351351351352, lift=2.1901211556383973), OrderedStatistic(items_base=frozenset({'4', 'A174'}), items_add=frozenset({'A192'}), confidence=0.8785046728971962, lift=2.174516517072268)]), RelationRecord(items=frozenset({'A101', 'A124', 'A153'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A124'}), items_add=frozenset({'A101', 'A153'}), confidence=0.6493506493506493, lift=6.304375236414072), OrderedStatistic(items_base=frozenset({'A153'}), items_add=frozenset({'A101', 'A124'}), confidence=0.925925925925926, lift=6.566850538481746), OrderedStatistic(items_base=frozenset({'A101', 'A124'}), items_add=frozenset({'A153'}), ...

# %%
print(len(association_results))
# Out:
# 402

# %%
def inspect(association_results):
    '''
    function to put the result in well organised pandas dataframe
    '''
    lhs         = [tuple(result[2][0][0]) for result in association_results]
    rhs         = [tuple(result[2][0][1]) for result in association_results]
    supports    = [result[1] for result in association_results]
    confidences = [result[2][0][2] for result in association_results]
    lifts       = [result[2][0][3] for result in association_results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

resultsinDataFrame = pd.DataFrame(inspect(association_results), columns = ['Item #1', 'Item #2', 'Support', 'Confidence', 'Lift'])
pd.DataFrame(resultsinDataFrame)
# Out:
#                         Item #1                  Item #2  Support  Confidence  \
# 0                       (A124,)                  (A153,)    0.104    0.675325
# 1                       (A174,)                  (A192,)    0.127    0.858108
# 2                       (A124,)                (A153, 1)    0.096    0.623377
# 3                       (A174,)                (1, A192)    0.125    0.844595
# 4                       (A153,)                (2, A124)    0.082    0.759259
# ..                          ...                      ...      ...         ...
# 397        (A75, 1, A191, A173)     (A201, A93, 4, A143)    0.053    0.609195
# 398      (A101, A152, A14, A75)     (A201, A93, 4, A143)    0.052    0.619048
# 399     (A101, A75, A191, A173)     (A201, A93, 4, A143)    0.054    0.635294
# 400      (A101, A152, A14, A75)  (A201, 1, 4, A143, A93)    0.051    0.607143
# 401  (A101, A173, 1, A75, A191)     (A201, A93, 4, A143)    0.050    0.625000
#
#          Lift
# 0    6.253006
# 1    2.124030
# 2    6.296734
# 3    2.111486
# 4    6.123059
# ..        ...
# 397  2.107943
# 398  2.142033
# 399  2.198250
# 400  2.176139
# 401  2.162630
#
# [402 rows x 5 columns]

# %%
resultsinDataFrame.nlargest(n=10, columns='Lift')
# Out:
#           Item #1                     Item #2  Support  Confidence      Lift
# 336  (A153, A173)     (A201, A101, A124, A93)    0.050    0.793651  7.631258
# 376     (2, A153)  (A101, A201, A124, 4, A93)    0.057    0.662791  7.618284
# 300     (2, A153)        (A101, A124, 4, A93)    0.057    0.662791  7.531712
# 163     (2, A153)           (A101, A124, A61)    0.053    0.616279  7.515598
# 306     (2, A153)     (A201, A101, A124, A61)    0.053    0.616279  7.515598
# 207  (A153, A173)           (A101, A124, A93)    0.050    0.793651  7.487272
# 388  (2, A153, 1)  (A101, A201, A124, 4, A93)    0.050    0.649351  7.463801
# 315       (A153,)  (A101, A201, A124, 4, A93)    0.070    0.648148  7.449979
# 377  (A153, A143)  (A101, A201, A124, 4, A93)    0.053    0.646341  7.429212
# 342  (2, A153, 1)        (A101, A124, 4, A93)    0.050    0.649351  7.378985

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    rule_string = "Rule: "
    i = 0
    for item1 in items:
        rule_string = rule_string + items[i] + " -> "
        i = i + 1
    #print("Rule: " + items[0] + " -> " + items[1])
    print(rule_string)

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: A153 -> A124 ->
# Support: 0.104
# Confidence: 0.6753246753246753
# Lift: 6.253006253006253
# =====================================
# Rule: A192 -> A174 ->
# Support: 0.127
# Confidence: 0.8581081081081081
# Lift: 2.124029970564624
# =====================================
# Rule: A153 -> A124 -> 1 ->
# Support: 0.096
# Confidence: 0.6233766233766234
# Lift: 6.296733569460842
# =====================================
# Rule: 1 -> A192 -> A174 ->
# Support: 0.125
# Confidence: 0.8445945945945946
# Lift: 2.1114864864864864
# =====================================
# Rule: 2 -> A153 -> A124 ->
# Support: 0.082
# Confidence: 0.7592592592592593
# Lift: 6.123058542413381
# =====================================
# Rule: 2 -> A192 -> A174 ->
# Support: 0.097
# Confidence: 0.6554054054054055
# Lift: 2.087278361163712
# =====================================
# Rule: A153 -> A124 -> 4 ->
# Support: 0.094
# Confidence: 0.6103896103896104
# Lift: 6.2926763957691785
# =====================================
# Rule: 4 -> A192 -> A174 ->
# Support: 0.094
# Confidence: 0.6351351351351352
# Lift: 2.1901211556383973
# =====================================
# Rule: A101 -> A124 -> A153 ->
# Support: 0.1
# Confidence: 0.6493506493506493
# Lift: 6.304375236414072
# =====================================
# Rule: A101 -> A192 -> A174 ->
# Support: 0.119
# Confidence: 0.8040540540540541
# Lift: 2.138441633122484
# =====================================
# Rule: A153 -> A124 -> A143 ->
# Support: 0.078
# Confidence: 0.7222222222222222
# Lift: 6.226053639846743
# =====================================
# Rule: A153 -> A124 -> A173 ->
# Support: 0.06
# Confidence: 0.6976744186046512
# Lift: 6.459948320413437
# =====================================
# Rule: A153 -> A124 -> A192 ->
# Support: 0.059
# Confidence: 0.67816091954023
# Lift: 6.2792677735206475
# =====================================
# Rule: A201 -> A153 -> A124 ->
# Support: 0.104
# Confidence: 0.6753246753246753
# Lift: 6.253006253006253
# =====================================
# Rule: A153 -> A124 -> A61 ->
# Support: 0.064
# Confidence: 0.7111111111111111
# Lift: 6.584362139917696
# =====================================
# Rule: A153 -> A124 -> A93 ->
# Support: 0.081
# Confidence: 0.75
# Lift: 6.578947368421052
# =====================================
# Rule: A192 -> A143 -> A174 ->
# Support: 0.097
# Confidence: 0.6554054054054055
# Lift: 2.0228561895228565
# =====================================
# Rule: A192 -> A152 -> A174 ->
# Support: 0.079
# Confidence: 0.8404255319148937
# Lift: 2.0802612176111226
# =====================================
# Rule: A201 -> A192 -> A174 ->
# Support: 0.125
# Confidence: 0.8445945945945946
# Lift: 2.1167784325679064
# =====================================
# Rule: A192 -> A32 -> A174 ->
# Support: 0.062
# Confidence: 0.8378378378378378
# Lift: 2.0738560342520738
# =====================================
# Rule: A192 -> A61 -> A174 ->
# Support: 0.083
# Confidence: 0.8645833333333334
# Lift: 2.1400577557755773
# =====================================
# Rule: A93 -> A192 -> A174 ->
# Support: 0.084
# Confidence: 0.8936170212765958
# Lift: 2.2119233199915738
# =====================================
# Rule: 2 -> A153 -> A124 -> 1 ->
# Support: 0.074
# Confidence: 0.6851851851851851
# Lift: 6.063585709603408
# =====================================
# Rule: 2 -> 1 -> A192 -> A174 ->
# Support: 0.095
# Confidence: 0.6418918918918919
# Lift: 2.070619006102877
# =====================================
# Rule: A153 -> A124 -> 1 -> 4 ->
# Support: 0.086
# Confidence: 0.7962962962962963
# Lift: 6.691565515094927
# =====================================
# Rule: A192 -> 1 -> 4 -> A174 ->
# Support: 0.093
# Confidence: 0.6283783783783784
# Lift: 2.1818693693693696
# =====================================
# Rule: A101 -> A124 -> 1 -> A153 ->
# Support: 0.092
# Confidence: 0.8518518518518519
# Lift: 6.552706552706552
# =====================================
# Rule: A101 -> 1 -> A192 -> A174 ->
# Support: 0.118
# Confidence: 0.7972972972972973
# Lift: 2.137526266212593
# =====================================
# Rule: A153 -> A124 -> 1 -> A143 ->
# Support: 0.071
# Confidence: 0.6574074074074073
# Lift: 6.031260618416581
# =====================================
# Rule: A153 -> A124 -> 1 -> A173 ->
# Support: 0.054
# Confidence: 0.627906976744186
# Lift: 6.342494714587738
# =====================================
# Rule: A153 -> A124 -> 1 -> A192 ->
# Support: 0.058
# Confidence: 0.6666666666666667
# Lift: 6.734006734006734
# =====================================
# Rule: A201 -> A153 -> A124 -> 1 ->
# Support: 0.096
# Confidence: 0.6233766233766234
# Lift: 6.296733569460842
# =====================================
# Rule: A153 -> A124 -> 1 -> A61 ->
# Support: 0.058
# Confidence: 0.6444444444444445
# Lift: 6.509539842873176
# =====================================
# Rule: A153 -> A124 -> 1 -> A93 ->
# Support: 0.074
# Confidence: 0.6851851851851851
# Lift: 6.588319088319088
# =====================================
# Rule: A192 -> 1 -> A143 -> A174 ->
# Support: 0.096
# Confidence: 0.6486486486486487
# Lift: 2.0082001506150116
# =====================================
# Rule: 1 -> A192 -> A152 -> A174 ->
# Support: 0.077
# Confidence: 0.8191489361702128
# Lift: 2.0478723404255317
# =====================================
# Rule: A201 -> 1 -> A192 -> A174 ->
# Support: 0.123
# Confidence: 0.8310810810810811
# Lift: 2.104002736914129
# =====================================
# Rule: 1 -> A192 -> A32 -> A174 ->
# Support: 0.062
# Confidence: 0.8378378378378378
# Lift: 2.0945945945945943
# =====================================
# Rule: 1 -> A192 -> A61 -> A174 ->
# Support: 0.081
# Confidence: 0.84375
# Lift: 2.109375
# =====================================
# Rule: A93 -> 1 -> A192 -> A174 ->
# Support: 0.082
# Confidence: 0.8723404255319149
# Lift: 2.1808510638297873
# =====================================
# Rule: 2 -> A153 -> A124 -> 4 ->
# Support: 0.074
# Confidence: 0.6851851851851851
# Lift: 6.6522833513124775
# =====================================
# Rule: 2 -> 4 -> A192 -> A174 ->
# Support: 0.068
# Confidence: 0.6355140186915889
# Lift: 2.0239299958330856
# =====================================
# Rule: 2 -> A101 -> A124 -> A153 ->
# Support: 0.081
# Confidence: 0.75
# Lift: 6.578947368421052
# =====================================
# Rule: 2 -> A101 -> A192 -> A174 ->
# Support: 0.092
# Confidence: 0.6216216216216216
# Lift: 2.1143592572164
# =====================================
# Rule: 2 -> A153 -> A124 -> A143 ->
# Support: 0.061
# Confidence: 0.7093023255813954
# Lift: 6.1146752205292705
# =====================================
# Rule: 2 -> A201 -> A153 -> A124 ->
# Support: 0.082
# Confidence: 0.7592592592592593
# Lift: 6.17283950617284
# =====================================
# Rule: 2 -> A153 -> A124 -> A61 ->
# Support: 0.053
# Confidence: 0.6162790697674418
# Lift: 6.847545219638243
# =====================================
# Rule: 2 -> A153 -> A124 -> A93 ->
# Support: 0.065
# Confidence: 0.6018518518518519
# Lift: 6.47152528872959
# =====================================
# Rule: 2 -> A192 -> A143 -> A174 ->
# Support: 0.071
# Confidence: 0.6339285714285714
# Lift: 2.0188808007279344
# =====================================
# Rule: 2 -> A192 -> A152 -> A174 ->
# Support: 0.06
# Confidence: 0.6382978723404255
# Lift: 2.0327957717847944
# =====================================
# Rule: 2 -> A201 -> A192 -> A174 ->
# Support: 0.095
# Confidence: 0.6418918918918919
# Lift: 2.070619006102877
# =====================================
# Rule: 2 -> A192 -> A61 -> A174 ->
# Support: 0.065
# Confidence: 0.6770833333333334
# Lift: 2.1563163481953294
# =====================================
# Rule: 2 -> A93 -> A192 -> A174 ->
# Support: 0.067
# Confidence: 0.7127659574468086
# Lift: 2.269955278493021
# =====================================
# Rule: A101 -> A124 -> 4 -> A153 ->
# Support: 0.09
# Confidence: 0.8333333333333333
# Lift: 7.062146892655367
# =====================================
# Rule: A101 -> 4 -> A192 -> A174 ->
# Support: 0.089
# Confidence: 0.6013513513513513
# Lift: 2.235506882347031
# =====================================
# Rule: A153 -> A124 -> 4 -> A143 ->
# Support: 0.071
# Confidence: 0.6574074074074073
# Lift: 6.777395952653683
# =====================================
# Rule: A153 -> A124 -> 4 -> A173 ->
# Support: 0.055
# Confidence: 0.6395348837209303
# Lift: 6.593143131143611
# =====================================
# Rule: A153 -> A124 -> 4 -> A192 ->
# Support: 0.052
# Confidence: 0.8524590163934426
# Lift: 6.557377049180327
# =====================================
# Rule: A201 -> A153 -> A124 -> 4 ->
# Support: 0.094
# Confidence: 0.6103896103896104
# Lift: 6.2926763957691785
# =====================================
# Rule: A153 -> A124 -> 4 -> A61 ->
# Support: 0.057
# Confidence: 0.6333333333333334
# Lift: 6.529209621993128
# =====================================
# Rule: A153 -> A124 -> 4 -> A93 ->
# Support: 0.072
# Confidence: 0.6666666666666666
# Lift: 7.017543859649122
# =====================================
# Rule: A192 -> 4 -> A143 -> A174 ->
# Support: 0.073
# Confidence: 0.6822429906542056
# Lift: 2.1056882427598937
# =====================================
# Rule: A191 -> A92 -> 4 -> A151 ->
# Support: 0.055
# Confidence: 0.6626506024096386
# Lift: 2.137582588418189
# =====================================
# Rule: A92 -> 4 -> A151 -> A32 ->
# Support: 0.054
# Confidence: 0.6428571428571428
# Lift: 2.073732718894009
# =====================================
# Rule: 4 -> A192 -> A152 -> A174 ->
# Support: 0.053
# Confidence: 0.8548387096774194
# Lift: 2.115937400191632
# =====================================
# Rule: A201 -> 4 -> A192 -> A174 ->
# Support: 0.093
# Confidence: 0.6283783783783784
# Lift: 2.1818693693693696
# =====================================
# Rule: 4 -> A192 -> A61 -> A174 ->
# Support: 0.06
# Confidence: 0.625
# Lift: 2.1551724137931036
# =====================================
# Rule: A93 -> 4 -> A192 -> A174 ->
# Support: 0.062
# Confidence: 0.6595744680851063
# Lift: 2.27439471753485
# =====================================
# Rule: A101 -> A124 -> A143 -> A153 ->
# Support: 0.075
# Confidence: 0.6944444444444444
# Lift: 6.4300411522633745
# =====================================
# Rule: A101 -> A124 -> A173 -> A153 ->
# Support: 0.058
# Confidence: 0.6744186046511629
# Lift: 6.547753443215174
# =====================================
# Rule: A101 -> A124 -> A153 -> A192 ->
# Support: 0.056
# Confidence: 0.6436781609195403
# Lift: 6.249302533199421
# =====================================
# Rule: A201 -> A101 -> A124 -> A153 ->
# Support: 0.1
# Confidence: 0.6493506493506493
# Lift: 6.304375236414072
# =====================================
# Rule: A61 -> A101 -> A124 -> A153 ->
# Support: 0.062
# Confidence: 0.6019417475728156
# Lift: 6.688241639697951
# =====================================
# Rule: A101 -> A124 -> A153 -> A93 ->
# Support: 0.079
# Confidence: 0.7314814814814815
# Lift: 6.900768693221524
# =====================================
# Rule: A192 -> A101 -> A143 -> A174 ->
# Support: 0.093
# Confidence: 0.6283783783783784
# Lift: 2.0535241123476418
# =====================================
# Rule: A101 -> A192 -> A152 -> A174 ->
# Support: 0.074
# Confidence: 0.7872340425531914
# Lift: 2.093707559981892
# =====================================
# Rule: A201 -> A101 -> A192 -> A174 ->
# Support: 0.117
# Confidence: 0.7905405405405406
# Lift: 2.130837036497414
# =====================================
# Rule: A101 -> A192 -> A32 -> A174 ->
# Support: 0.059
# Confidence: 0.7972972972972973
# Lift: 2.1204715353651524
# =====================================
# Rule: A101 -> A192 -> A61 -> A174 ->
# Support: 0.077
# Confidence: 0.8020833333333333
# Lift: 2.133200354609929
# =====================================
# Rule: A101 -> A93 -> A192 -> A174 ->
# Support: 0.077
# Confidence: 0.8191489361702128
# Lift: 2.1785875961973744
# =====================================
# Rule: A201 -> A153 -> A124 -> A143 ->
# Support: 0.078
# Confidence: 0.7222222222222222
# Lift: 6.280193236714975
# =====================================
# Rule: A153 -> A124 -> A143 -> A93 ->
# Support: 0.06
# Confidence: 0.7317073170731707
# Lift: 6.418485237483954
# =====================================
# Rule: A201 -> A153 -> A124 -> A173 ->
# Support: 0.06
# Confidence: 0.6976744186046512
# Lift: 6.459948320413437
# =====================================
# Rule: A153 -> A124 -> A173 -> A93 ->
# Support: 0.05
# Confidence: 0.7936507936507937
# Lift: 6.961849067112225
# =====================================
# Rule: A201 -> A153 -> A124 -> A192 ->
# Support: 0.059
# Confidence: 0.67816091954023
# Lift: 6.2792677735206475
# =====================================
# Rule: A201 -> A153 -> A124 -> A61 ->
# Support: 0.064
# Confidence: 0.7111111111111111
# Lift: 6.584362139917696
# =====================================
# Rule: A201 -> A153 -> A124 -> A93 ->
# Support: 0.081
# Confidence: 0.75
# Lift: 6.696428571428571
# =====================================
# Rule: A192 -> A143 -> A152 -> A174 ->
# Support: 0.06
# Confidence: 0.857142857142857
# Lift: 2.121640735502121
# =====================================
# Rule: A192 -> A201 -> A143 -> A174 ->
# Support: 0.096
# Confidence: 0.6486486486486487
# Lift: 2.027027027027027
# =====================================
# Rule: A192 -> A143 -> A32 -> A174 ->
# Support: 0.053
# Confidence: 0.7162162162162162
# Lift: 2.2105438772105437
# =====================================
# Rule: A192 -> A143 -> A61 -> A174 ->
# Support: 0.063
# Confidence: 0.65625
# Lift: 2.025462962962963
# =====================================
# Rule: A192 -> A93 -> A143 -> A174 ->
# Support: 0.062
# Confidence: 0.6595744680851063
# Lift: 2.0357236669293406
# =====================================
# Rule: A201 -> A192 -> A152 -> A174 ->
# Support: 0.077
# Confidence: 0.8191489361702128
# Lift: 2.053004852556924
# =====================================
# Rule: A93 -> A192 -> A152 -> A174 ->
# Support: 0.052
# Confidence: 0.8813559322033898
# Lift: 2.1815740896123508
# =====================================
# Rule: A201 -> A192 -> A32 -> A174 ->
# Support: 0.061
# Confidence: 0.8243243243243243
# Lift: 2.0659757501862765
# =====================================
# Rule: A201 -> A192 -> A61 -> A174 ->
# Support: 0.081
# Confidence: 0.84375
# Lift: 2.1146616541353382
# =====================================
# Rule: A201 -> A93 -> A192 -> A174 ->
# Support: 0.084
# Confidence: 0.8936170212765958
# Lift: 2.2396416573348263
# =====================================
# Rule: A93 -> A192 -> A61 -> A174 ->
# Support: 0.052
# Confidence: 0.9122807017543859
# Lift: 2.258120548896995
# =====================================
# Rule: A124 -> 1 -> 4 -> 2 -> A153 ->
# Support: 0.066
# Confidence: 0.6111111111111112
# Lift: 6.642512077294687
# =====================================
# Rule: 1 -> 4 -> A192 -> 2 -> A174 ->
# Support: 0.067
# Confidence: 0.6261682242990655
# Lift: 2.019897497738921
# =====================================
# Rule: A101 -> A124 -> 1 -> 2 -> A153 ->
# Support: 0.073
# Confidence: 0.6759259259259259
# Lift: 6.562387630348796
# =====================================
# Rule: A101 -> 1 -> A192 -> 2 -> A174 ->
# Support: 0.091
# Confidence: 0.6148648648648649
# Lift: 2.1129376799479895
# =====================================
# Rule: A124 -> 1 -> 2 -> A143 -> A153 ->
# Support: 0.054
# Confidence: 0.627906976744186
# Lift: 5.760614465542991
# =====================================
# Rule: A201 -> A124 -> 1 -> 2 -> A153 ->
# Support: 0.074
# Confidence: 0.6851851851851851
# Lift: 6.117724867724867
# =====================================
# Rule: A124 -> 1 -> 2 -> A153 -> A93 ->
# Support: 0.058
# Confidence: 0.6744186046511629
# Lift: 6.484794275491951
# =====================================
# Rule: 1 -> A192 -> 2 -> A174 -> A143 ->
# Support: 0.07
# Confidence: 0.625
# Lift: 2.0161290322580645
# =====================================
# Rule: 1 -> A192 -> 2 -> A174 -> A152 ->
# Support: 0.058
# Confidence: 0.6304347826086957
# Lift: 2.007754084741069
# =====================================
# Rule: A201 -> 1 -> A192 -> 2 -> A174 ->
# Support: 0.093
# Confidence: 0.6283783783783784
# Lift: 2.0535241123476418
# =====================================
# Rule: 1 -> A61 -> A192 -> 2 -> A174 ->
# Support: 0.063
# Confidence: 0.65625
# Lift: 2.116935483870968
# =====================================
# Rule: 1 -> A192 -> 2 -> A174 -> A93 ->
# Support: 0.065
# Confidence: 0.6914893617021277
# Lift: 2.230610844200412
# =====================================
# Rule: A101 -> A124 -> 1 -> 4 -> A153 ->
# Support: 0.082
# Confidence: 0.7592592592592593
# Lift: 7.095880927656629
# =====================================
# Rule: A101 -> 1 -> 4 -> A192 -> A174 ->
# Support: 0.088
# Confidence: 0.6027397260273972
# Lift: 2.2406681264959003
# =====================================
# Rule: A124 -> 1 -> 4 -> A143 -> A153 ->
# Support: 0.064
# Confidence: 0.6464646464646464
# Lift: 6.664583984171612
# =====================================
# Rule: A124 -> 1 -> 4 -> A192 -> A153 ->
# Support: 0.051
# Confidence: 0.8360655737704917
# Lift: 7.02576112412178
# =====================================
# Rule: A201 -> A124 -> 1 -> 4 -> A153 ->
# Support: 0.086
# Confidence: 0.7962962962962963
# Lift: 6.74827369742624
# =====================================
# Rule: A124 -> 1 -> 4 -> A61 -> A153 ->
# Support: 0.051
# Confidence: 0.7611940298507461
# Lift: 6.3965884861407245
# =====================================
# Rule: A124 -> 1 -> 4 -> A153 -> A93 ->
# Support: 0.065
# Confidence: 0.6018518518518519
# Lift: 7.080610021786492
# =====================================
# Rule: 1 -> 4 -> A192 -> A174 -> A143 ->
# Support: 0.073
# Confidence: 0.6822429906542056
# Lift: 2.1122074014062093
# =====================================
# Rule: A173 -> A92 -> 1 -> 4 -> A151 ->
# Support: 0.053
# Confidence: 0.6235294117647058
# Lift: 2.0113851992409866
# =====================================
# Rule: A92 -> 1 -> 4 -> A151 -> A191 ->
# Support: 0.055
# Confidence: 0.6626506024096386
# Lift: 2.1445003314227784
# =====================================
# Rule: A92 -> 1 -> 4 -> A151 -> A32 ->
# Support: 0.054
# Confidence: 0.6428571428571428
# Lift: 2.0804438280166435
# =====================================
# Rule: 1 -> 4 -> A192 -> A174 -> A152 ->
# Support: 0.052
# Confidence: 0.8387096774193548
# Lift: 2.0967741935483866
# =====================================
# Rule: A201 -> 1 -> 4 -> A192 -> A174 ->
# Support: 0.092
# Confidence: 0.6216216216216216
# Lift: 2.1735021735021736
# =====================================
# Rule: 1 -> 4 -> A61 -> A192 -> A174 ->
# Support: 0.059
# Confidence: 0.6145833333333333
# Lift: 2.1339699074074074
# =====================================
# Rule: 1 -> 4 -> A192 -> A174 -> A93 ->
# Support: 0.061
# Confidence: 0.648936170212766
# Lift: 2.2532505910165486
# =====================================
# Rule: A101 -> A124 -> 1 -> A143 -> A153 ->
# Support: 0.068
# Confidence: 0.6296296296296297
# Lift: 6.233956729006234
# =====================================
# Rule: A101 -> A173 -> A124 -> 1 -> A153 ->
# Support: 0.052
# Confidence: 0.6046511627906977
# Lift: 6.432459178624444
# =====================================
# Rule: A101 -> A124 -> 1 -> A192 -> A153 ->
# Support: 0.055
# Confidence: 0.632183908045977
# Lift: 6.725360723893372
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> A153 ->
# Support: 0.092
# Confidence: 0.8518518518518519
# Lift: 6.655092592592593
# =====================================
# Rule: A101 -> A124 -> 1 -> A61 -> A153 ->
# Support: 0.056
# Confidence: 0.6222222222222222
# Lift: 6.619385342789598
# =====================================
# Rule: A101 -> A124 -> 1 -> A153 -> A93 ->
# Support: 0.072
# Confidence: 0.6666666666666666
# Lift: 6.944444444444444
# =====================================
# Rule: A101 -> 1 -> A192 -> A174 -> A143 ->
# Support: 0.093
# Confidence: 0.6283783783783784
# Lift: 2.0535241123476418
# =====================================
# Rule: A101 -> 1 -> A192 -> A174 -> A152 ->
# Support: 0.073
# Confidence: 0.776595744680851
# Lift: 2.0820261251497345
# =====================================
# Rule: A101 -> A201 -> 1 -> A192 -> A174 ->
# Support: 0.116
# Confidence: 0.7837837837837839
# Lift: 2.129847238542891
# =====================================
# Rule: A101 -> 1 -> A192 -> A174 -> A32 ->
# Support: 0.059
# Confidence: 0.7972972972972973
# Lift: 2.137526266212593
# =====================================
# Rule: A101 -> 1 -> A61 -> A192 -> A174 ->
# Support: 0.076
# Confidence: 0.7916666666666666
# Lift: 2.1224307417336905
# =====================================
# Rule: A101 -> 1 -> A192 -> A174 -> A93 ->
# Support: 0.076
# Confidence: 0.8085106382978723
# Lift: 2.1675888426216416
# =====================================
# Rule: A201 -> A124 -> 1 -> A143 -> A153 ->
# Support: 0.071
# Confidence: 0.6574074074074073
# Lift: 6.08710562414266
# =====================================
# Rule: A124 -> 1 -> A143 -> A153 -> A93 ->
# Support: 0.054
# Confidence: 0.6585365853658536
# Lift: 6.3320825515947465
# =====================================
# Rule: A173 -> A201 -> A124 -> 1 -> A153 ->
# Support: 0.054
# Confidence: 0.627906976744186
# Lift: 6.342494714587738
# =====================================
# Rule: A201 -> A124 -> 1 -> A192 -> A153 ->
# Support: 0.058
# Confidence: 0.6666666666666667
# Lift: 6.734006734006734
# =====================================
# Rule: A201 -> A124 -> 1 -> A61 -> A153 ->
# Support: 0.058
# Confidence: 0.6444444444444445
# Lift: 6.509539842873176
# =====================================
# Rule: A201 -> A124 -> 1 -> A153 -> A93 ->
# Support: 0.074
# Confidence: 0.6851851851851851
# Lift: 6.717501815541031
# =====================================
# Rule: 1 -> A192 -> A174 -> A143 -> A152 ->
# Support: 0.059
# Confidence: 0.8428571428571427
# Lift: 2.1071428571428568
# =====================================
# Rule: A201 -> 1 -> A192 -> A174 -> A143 ->
# Support: 0.095
# Confidence: 0.6418918918918919
# Lift: 2.012200288062357
# =====================================
# Rule: 1 -> A192 -> A174 -> A143 -> A32 ->
# Support: 0.053
# Confidence: 0.7162162162162162
# Lift: 2.217387666304075
# =====================================
# Rule: 1 -> A61 -> A192 -> A174 -> A143 ->
# Support: 0.062
# Confidence: 0.6595744680851063
# Lift: 2.0357236669293406
# =====================================
# Rule: 1 -> A192 -> A174 -> A143 -> A93 ->
# Support: 0.061
# Confidence: 0.648936170212766
# Lift: 2.009090310256241
# =====================================
# Rule: A201 -> 1 -> A192 -> A174 -> A152 ->
# Support: 0.075
# Confidence: 0.7978723404255319
# Lift: 2.01992997576084
# =====================================
# Rule: 1 -> A192 -> A174 -> A93 -> A152 ->
# Support: 0.05
# Confidence: 0.8474576271186441
# Lift: 2.1186440677966103
# =====================================
# Rule: A201 -> 1 -> A192 -> A174 -> A32 ->
# Support: 0.061
# Confidence: 0.8243243243243243
# Lift: 2.0868970236058844
# =====================================
# Rule: A201 -> 1 -> A61 -> A192 -> A174 ->
# Support: 0.079
# Confidence: 0.8229166666666666
# Lift: 2.083333333333333
# =====================================
# Rule: A201 -> 1 -> A192 -> A174 -> A93 ->
# Support: 0.082
# Confidence: 0.8723404255319149
# Lift: 2.2084567734985185
# =====================================
# Rule: 1 -> A61 -> A192 -> A174 -> A93 ->
# Support: 0.05
# Confidence: 0.8771929824561404
# Lift: 2.192982456140351
# =====================================
# Rule: A101 -> A124 -> 4 -> 2 -> A153 ->
# Support: 0.073
# Confidence: 0.6759259259259259
# Lift: 7.19070133963751
# =====================================
# Rule: A101 -> 4 -> A92 -> 2 -> A151 ->
# Support: 0.052
# Confidence: 0.6265060240963854
# Lift: 2.0209871745044694
# =====================================
# Rule: A101 -> 4 -> A192 -> 2 -> A174 ->
# Support: 0.065
# Confidence: 0.6074766355140188
# Lift: 2.0662470595714924
# =====================================
# Rule: A124 -> 4 -> 2 -> A143 -> A153 ->
# Support: 0.055
# Confidence: 0.6395348837209303
# Lift: 6.593143131143611
# =====================================
# Rule: A201 -> A124 -> 4 -> 2 -> A153 ->
# Support: 0.074
# Confidence: 0.6851851851851851
# Lift: 6.6522833513124775
# =====================================
# Rule: A124 -> 4 -> 2 -> A153 -> A93 ->
# Support: 0.057
# Confidence: 0.6627906976744187
# Lift: 6.9767441860465125
# =====================================
# Rule: A201 -> 4 -> A192 -> 2 -> A174 ->
# Support: 0.067
# Confidence: 0.6261682242990655
# Lift: 2.019897497738921
# =====================================
# Rule: A101 -> A124 -> 2 -> A143 -> A153 ->
# Support: 0.06
# Confidence: 0.6976744186046512
# Lift: 6.459948320413437
# =====================================
# Rule: A101 -> A201 -> A124 -> 2 -> A153 ->
# Support: 0.081
# Confidence: 0.75
# Lift: 6.6371681415929205
# =====================================
# Rule: A101 -> A124 -> A61 -> 2 -> A153 ->
# Support: 0.053
# Confidence: 0.6162790697674418
# Lift: 7.515598411798071
# =====================================
# Rule: A101 -> A124 -> 2 -> A153 -> A93 ->
# Support: 0.065
# Confidence: 0.6018518518518519
# Lift: 6.917837377607493
# =====================================
# Rule: A101 -> A192 -> 2 -> A174 -> A143 ->
# Support: 0.068
# Confidence: 0.6071428571428572
# Lift: 2.0651117589893104
# =====================================
# Rule: A101 -> A192 -> 2 -> A174 -> A152 ->
# Support: 0.056
# Confidence: 0.6363636363636365
# Lift: 2.0266357845975684
# =====================================
# Rule: A101 -> A201 -> A192 -> 2 -> A174 ->
# Support: 0.09
# Confidence: 0.6081081081081081
# Lift: 2.0969245107176144
# =====================================
# Rule: A101 -> A61 -> A192 -> 2 -> A174 ->
# Support: 0.061
# Confidence: 0.6354166666666666
# Lift: 2.161281179138322
# =====================================
# Rule: A101 -> A192 -> 2 -> A174 -> A93 ->
# Support: 0.063
# Confidence: 0.6702127659574468
# Lift: 2.2796352583586628
# =====================================
# Rule: A201 -> A124 -> 2 -> A143 -> A153 ->
# Support: 0.061
# Confidence: 0.7093023255813954
# Lift: 6.167846309403438
# =====================================
# Rule: A201 -> A124 -> A61 -> 2 -> A153 ->
# Support: 0.053
# Confidence: 0.6162790697674418
# Lift: 6.847545219638243
# =====================================
# Rule: A201 -> A124 -> 2 -> A153 -> A93 ->
# Support: 0.065
# Confidence: 0.6018518518518519
# Lift: 6.541867954911433
# =====================================
# Rule: A201 -> A192 -> 2 -> A174 -> A143 ->
# Support: 0.07
# Confidence: 0.625
# Lift: 2.0161290322580645
# =====================================
# Rule: A201 -> A192 -> 2 -> A174 -> A152 ->
# Support: 0.058
# Confidence: 0.6304347826086957
# Lift: 2.007754084741069
# =====================================
# Rule: A201 -> A61 -> A192 -> 2 -> A174 ->
# Support: 0.063
# Confidence: 0.65625
# Lift: 2.116935483870968
# =====================================
# Rule: A201 -> A192 -> 2 -> A174 -> A93 ->
# Support: 0.067
# Confidence: 0.7127659574468086
# Lift: 2.299245024021963
# =====================================
# Rule: A101 -> A124 -> 4 -> A143 -> A153 ->
# Support: 0.068
# Confidence: 0.6296296296296297
# Lift: 7.074490220557637
# =====================================
# Rule: A101 -> A173 -> A124 -> 4 -> A153 ->
# Support: 0.053
# Confidence: 0.6162790697674418
# Lift: 6.698685540950455
# =====================================
# Rule: A101 -> A201 -> A124 -> 4 -> A153 ->
# Support: 0.09
# Confidence: 0.8333333333333333
# Lift: 7.1225071225071215
# =====================================
# Rule: A101 -> A124 -> 4 -> A61 -> A153 ->
# Support: 0.055
# Confidence: 0.6111111111111112
# Lift: 6.642512077294687
# =====================================
# Rule: A101 -> A124 -> 4 -> A153 -> A93 ->
# Support: 0.07
# Confidence: 0.6481481481481483
# Lift: 7.365319865319867
# =====================================
# Rule: A101 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.082
# Confidence: 0.7130434782608696
# Lift: 2.0199531962064294
# =====================================
# Rule: A101 -> 4 -> A192 -> A174 -> A143 ->
# Support: 0.07
# Confidence: 0.6542056074766356
# Lift: 2.137926821819071
# =====================================
# Rule: A101 -> A201 -> 4 -> A92 -> A151 ->
# Support: 0.071
# Confidence: 0.6068376068376068
# Lift: 2.0027643790020027
# =====================================
# Rule: A101 -> 4 -> A92 -> A151 -> A32 ->
# Support: 0.051
# Confidence: 0.6071428571428571
# Lift: 2.1453811206461384
# =====================================
# Rule: A101 -> 4 -> A192 -> A174 -> A152 ->
# Support: 0.051
# Confidence: 0.8225806451612903
# Lift: 2.187714481811942
# =====================================
# Rule: A101 -> A201 -> 4 -> A192 -> A174 ->
# Support: 0.088
# Confidence: 0.822429906542056
# Lift: 2.216792200921984
# =====================================
# Rule: A101 -> 4 -> A61 -> A192 -> A174 ->
# Support: 0.057
# Confidence: 0.8382352941176471
# Lift: 2.229349186483104
# =====================================
# Rule: A101 -> 4 -> A192 -> A174 -> A93 ->
# Support: 0.058
# Confidence: 0.6170212765957447
# Lift: 2.2937593925492368
# =====================================
# Rule: A201 -> A124 -> 4 -> A143 -> A153 ->
# Support: 0.071
# Confidence: 0.6574074074074073
# Lift: 6.777395952653683
# =====================================
# Rule: A124 -> 4 -> A143 -> A153 -> A93 ->
# Support: 0.054
# Confidence: 0.6585365853658536
# Lift: 6.931964056482669
# =====================================
# Rule: A173 -> A201 -> A124 -> 4 -> A153 ->
# Support: 0.055
# Confidence: 0.6395348837209303
# Lift: 6.593143131143611
# =====================================
# Rule: A201 -> A124 -> 4 -> A192 -> A153 ->
# Support: 0.052
# Confidence: 0.8524590163934426
# Lift: 6.608209429406531
# =====================================
# Rule: A201 -> A124 -> 4 -> A61 -> A153 ->
# Support: 0.057
# Confidence: 0.6333333333333334
# Lift: 6.529209621993128
# =====================================
# Rule: A201 -> A124 -> 4 -> A153 -> A93 ->
# Support: 0.072
# Confidence: 0.6666666666666666
# Lift: 7.092198581560283
# =====================================
# Rule: 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.071
# Confidence: 0.617391304347826
# Lift: 2.051133901487794
# =====================================
# Rule: A201 -> 4 -> A192 -> A174 -> A143 ->
# Support: 0.072
# Confidence: 0.6728971962616822
# Lift: 2.102803738317757
# =====================================
# Rule: 4 -> A93 -> A75 -> A143 -> A34 ->
# Support: 0.065
# Confidence: 0.625
# Lift: 2.0764119601328903
# =====================================
# Rule: A201 -> A92 -> 4 -> A151 -> A191 ->
# Support: 0.054
# Confidence: 0.6506024096385542
# Lift: 2.147202672074436
# =====================================
# Rule: A201 -> A92 -> 4 -> A151 -> A32 ->
# Support: 0.054
# Confidence: 0.6428571428571428
# Lift: 2.1216407355021216
# =====================================
# Rule: A201 -> 4 -> A192 -> A174 -> A152 ->
# Support: 0.052
# Confidence: 0.8387096774193548
# Lift: 2.1020292667151748
# =====================================
# Rule: A201 -> 4 -> A61 -> A192 -> A174 ->
# Support: 0.059
# Confidence: 0.6145833333333333
# Lift: 2.1339699074074074
# =====================================
# Rule: A201 -> 4 -> A192 -> A174 -> A93 ->
# Support: 0.062
# Confidence: 0.6595744680851063
# Lift: 2.2901891252955084
# =====================================
# Rule: A101 -> A201 -> A124 -> A143 -> A153 ->
# Support: 0.075
# Confidence: 0.6944444444444444
# Lift: 6.4901349948078915
# =====================================
# Rule: A101 -> A124 -> A143 -> A153 -> A93 ->
# Support: 0.059
# Confidence: 0.7195121951219512
# Lift: 6.787850897376898
# =====================================
# Rule: A101 -> A173 -> A201 -> A124 -> A153 ->
# Support: 0.058
# Confidence: 0.6744186046511629
# Lift: 6.547753443215174
# =====================================
# Rule: A101 -> A173 -> A124 -> A153 -> A93 ->
# Support: 0.05
# Confidence: 0.7936507936507937
# Lift: 7.487271638215035
# =====================================
# Rule: A101 -> A201 -> A124 -> A192 -> A153 ->
# Support: 0.056
# Confidence: 0.6436781609195403
# Lift: 6.249302533199421
# =====================================
# Rule: A101 -> A201 -> A124 -> A61 -> A153 ->
# Support: 0.062
# Confidence: 0.6019417475728156
# Lift: 6.688241639697951
# =====================================
# Rule: A101 -> A201 -> A124 -> A153 -> A93 ->
# Support: 0.079
# Confidence: 0.7314814814814815
# Lift: 7.033475783475784
# =====================================
# Rule: A101 -> A192 -> A174 -> A143 -> A152 ->
# Support: 0.058
# Confidence: 0.6170212765957447
# Lift: 2.0164094006396884
# =====================================
# Rule: A101 -> A201 -> A192 -> A174 -> A143 ->
# Support: 0.092
# Confidence: 0.6216216216216216
# Lift: 2.058349740468946
# =====================================
# Rule: A101 -> A192 -> A174 -> A143 -> A32 ->
# Support: 0.052
# Confidence: 0.7027027027027027
# Lift: 2.2964140611199437
# =====================================
# Rule: A101 -> A61 -> A192 -> A174 -> A143 ->
# Support: 0.061
# Confidence: 0.6354166666666666
# Lift: 2.076525054466231
# =====================================
# Rule: A101 -> A192 -> A174 -> A143 -> A93 ->
# Support: 0.059
# Confidence: 0.6276595744680851
# Lift: 2.0511750799610624
# =====================================
# Rule: A101 -> A201 -> A192 -> A174 -> A152 ->
# Support: 0.072
# Confidence: 0.7659574468085106
# Lift: 2.0645753283248265
# =====================================
# Rule: A101 -> A201 -> A192 -> A174 -> A32 ->
# Support: 0.058
# Confidence: 0.7837837837837839
# Lift: 2.1126247541341883
# =====================================
# Rule: A101 -> A201 -> A61 -> A192 -> A174 ->
# Support: 0.075
# Confidence: 0.78125
# Lift: 2.1057951482479784
# =====================================
# Rule: A101 -> A201 -> A192 -> A174 -> A93 ->
# Support: 0.077
# Confidence: 0.8191489361702128
# Lift: 2.207948615014051
# =====================================
# Rule: A201 -> A124 -> A143 -> A153 -> A93 ->
# Support: 0.06
# Confidence: 0.7317073170731707
# Lift: 6.533101045296167
# =====================================
# Rule: A173 -> A201 -> A124 -> A153 -> A93 ->
# Support: 0.05
# Confidence: 0.7936507936507937
# Lift: 7.086167800453516
# =====================================
# Rule: A201 -> A14 -> A43 -> A143 -> A34 ->
# Support: 0.051
# Confidence: 0.6375
# Lift: 2.0047169811320753
# =====================================
# Rule: A201 -> A192 -> A174 -> A143 -> A152 ->
# Support: 0.059
# Confidence: 0.8428571428571427
# Lift: 2.1124239169351946
# =====================================
# Rule: A201 -> A192 -> A174 -> A143 -> A32 ->
# Support: 0.052
# Confidence: 0.7027027027027027
# Lift: 2.195945945945946
# =====================================
# Rule: A201 -> A61 -> A192 -> A174 -> A143 ->
# Support: 0.062
# Confidence: 0.6458333333333334
# Lift: 2.0182291666666665
# =====================================
# Rule: A201 -> A192 -> A174 -> A143 -> A93 ->
# Support: 0.062
# Confidence: 0.6595744680851063
# Lift: 2.0611702127659575
# =====================================
# Rule: A201 -> A192 -> A174 -> A93 -> A152 ->
# Support: 0.052
# Confidence: 0.8813559322033898
# Lift: 2.208912110785438
# =====================================
# Rule: A201 -> A61 -> A192 -> A174 -> A93 ->
# Support: 0.052
# Confidence: 0.9122807017543859
# Lift: 2.2864177988831726
# =====================================
# Rule: A101 -> A124 -> 1 -> 4 -> 2 -> A153 ->
# Support: 0.065
# Confidence: 0.6018518518518519
# Lift: 7.251227130745203
# =====================================
# Rule: A101 -> 1 -> 4 -> A92 -> 2 -> A151 ->
# Support: 0.052
# Confidence: 0.6265060240963854
# Lift: 2.027527586072445
# =====================================
# Rule: A101 -> 1 -> 4 -> A174 -> 2 -> A192 ->
# Support: 0.064
# Confidence: 0.6037735849056604
# Lift: 2.0536516493389807
# =====================================
# Rule: A201 -> A124 -> 1 -> 4 -> 2 -> A153 ->
# Support: 0.066
# Confidence: 0.6111111111111112
# Lift: 6.642512077294687
# =====================================
# Rule: A124 -> 1 -> 4 -> 2 -> A153 -> A93 ->
# Support: 0.05
# Confidence: 0.6493506493506493
# Lift: 6.83526999316473
# =====================================
# Rule: A201 -> 1 -> 4 -> A192 -> 2 -> A174 ->
# Support: 0.066
# Confidence: 0.6168224299065421
# Lift: 2.015759574857981
# =====================================
# Rule: A101 -> A124 -> 1 -> 2 -> A143 -> A153 ->
# Support: 0.053
# Confidence: 0.6162790697674418
# Lift: 6.101772967994473
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> 2 -> A153 ->
# Support: 0.073
# Confidence: 0.6759259259259259
# Lift: 6.6267247639796665
# =====================================
# Rule: A101 -> A124 -> 1 -> 2 -> A153 -> A93 ->
# Support: 0.058
# Confidence: 0.6744186046511629
# Lift: 7.025193798449613
# =====================================
# Rule: A101 -> 1 -> A174 -> 2 -> A192 -> A143 ->
# Support: 0.068
# Confidence: 0.6071428571428572
# Lift: 2.0864015709376535
# =====================================
# Rule: A101 -> 1 -> A174 -> 2 -> A192 -> A152 ->
# Support: 0.055
# Confidence: 0.625
# Lift: 2.0161290322580645
# =====================================
# Rule: A101 -> A201 -> 1 -> A192 -> 2 -> A174 ->
# Support: 0.089
# Confidence: 0.6013513513513513
# Lift: 2.0953008757886806
# =====================================
# Rule: A101 -> 1 -> A61 -> A192 -> 2 -> A174 ->
# Support: 0.06
# Confidence: 0.625
# Lift: 2.147766323024055
# =====================================
# Rule: A101 -> 1 -> A192 -> 2 -> A174 -> A93 ->
# Support: 0.062
# Confidence: 0.6595744680851063
# Lift: 2.2665789281275135
# =====================================
# Rule: A201 -> A124 -> 1 -> 2 -> A143 -> A153 ->
# Support: 0.054
# Confidence: 0.627906976744186
# Lift: 5.813953488372093
# =====================================
# Rule: A201 -> A124 -> 1 -> 2 -> A153 -> A93 ->
# Support: 0.058
# Confidence: 0.6744186046511629
# Lift: 6.611947104423166
# =====================================
# Rule: A201 -> 1 -> A192 -> 2 -> A174 -> A143 ->
# Support: 0.069
# Confidence: 0.6160714285714286
# Lift: 2.0133053221288515
# =====================================
# Rule: A201 -> 1 -> A61 -> A192 -> 2 -> A174 ->
# Support: 0.061
# Confidence: 0.6354166666666666
# Lift: 2.076525054466231
# =====================================
# Rule: A201 -> 1 -> A192 -> 2 -> A174 -> A93 ->
# Support: 0.065
# Confidence: 0.6914893617021277
# Lift: 2.2597691558893063
# =====================================
# Rule: A101 -> A124 -> 1 -> 4 -> A143 -> A153 ->
# Support: 0.061
# Confidence: 0.6161616161616161
# Lift: 6.923164226535013
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> 4 -> A153 ->
# Support: 0.082
# Confidence: 0.7592592592592593
# Lift: 7.162823200559051
# =====================================
# Rule: A101 -> A124 -> 1 -> 4 -> A153 -> A93 ->
# Support: 0.063
# Confidence: 0.6363636363636364
# Lift: 7.231404958677686
# =====================================
# Rule: A101 -> 1 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.079
# Confidence: 0.6869565217391305
# Lift: 2.0324157447903266
# =====================================
# Rule: A101 -> 1 -> 4 -> A174 -> A192 -> A143 ->
# Support: 0.07
# Confidence: 0.6542056074766356
# Lift: 2.137926821819071
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A92 -> A151 ->
# Support: 0.071
# Confidence: 0.6068376068376068
# Lift: 2.009396049131148
# =====================================
# Rule: A101 -> 1 -> 4 -> A92 -> A151 -> A32 ->
# Support: 0.051
# Confidence: 0.6071428571428571
# Lift: 2.1529888551165146
# =====================================
# Rule: A101 -> 1 -> 4 -> A174 -> A192 -> A152 ->
# Support: 0.05
# Confidence: 0.8064516129032259
# Lift: 2.1620686673008738
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A192 -> A174 ->
# Support: 0.087
# Confidence: 0.8130841121495327
# Lift: 2.2094676960585127
# =====================================
# Rule: A101 -> 1 -> 4 -> A61 -> A192 -> A174 ->
# Support: 0.056
# Confidence: 0.8235294117647058
# Lift: 2.2078536508437154
# =====================================
# Rule: A101 -> 1 -> 4 -> A192 -> A174 -> A93 ->
# Support: 0.057
# Confidence: 0.6063829787234043
# Lift: 2.2710972985895292
# =====================================
# Rule: A201 -> A124 -> 1 -> 4 -> A143 -> A153 ->
# Support: 0.064
# Confidence: 0.6464646464646464
# Lift: 6.664583984171612
# =====================================
# Rule: A201 -> A124 -> 1 -> 4 -> A192 -> A153 ->
# Support: 0.051
# Confidence: 0.8360655737704917
# Lift: 7.085301472631286
# =====================================
# Rule: A201 -> A124 -> 1 -> 4 -> A61 -> A153 ->
# Support: 0.051
# Confidence: 0.7611940298507461
# Lift: 6.450796863141917
# =====================================
# Rule: A201 -> A124 -> 1 -> 4 -> A153 -> A93 ->
# Support: 0.065
# Confidence: 0.6018518518518519
# Lift: 7.1649029982363315
# =====================================
# Rule: 1 -> 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.069
# Confidence: 0.6
# Lift: 2.061855670103093
# =====================================
# Rule: 1 -> 4 -> A14 -> A75 -> A93 -> A152 ->
# Support: 0.065
# Confidence: 0.7386363636363638
# Lift: 2.0071640316205537
# =====================================
# Rule: A173 -> 1 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.056
# Confidence: 0.7466666666666667
# Lift: 2.028985507246377
# =====================================
# Rule: A201 -> 1 -> 4 -> A192 -> A174 -> A143 ->
# Support: 0.072
# Confidence: 0.6728971962616822
# Lift: 2.109395599566402
# =====================================
# Rule: 1 -> 4 -> A93 -> A75 -> A143 -> A34 ->
# Support: 0.064
# Confidence: 0.6153846153846154
# Lift: 2.1147237642083003
# =====================================
# Rule: A173 -> A201 -> 1 -> 4 -> A92 -> A151 ->
# Support: 0.052
# Confidence: 0.6117647058823529
# Lift: 2.01902543195496
# =====================================
# Rule: A201 -> 1 -> 4 -> A151 -> A92 -> A191 ->
# Support: 0.054
# Confidence: 0.6506024096385542
# Lift: 2.1543126146971994
# =====================================
# Rule: A201 -> 1 -> 4 -> A92 -> A151 -> A32 ->
# Support: 0.054
# Confidence: 0.6428571428571428
# Lift: 2.128666035950804
# =====================================
# Rule: A201 -> 1 -> 4 -> A192 -> A174 -> A152 ->
# Support: 0.051
# Confidence: 0.8225806451612903
# Lift: 2.08248264597795
# =====================================
# Rule: A201 -> 1 -> 4 -> A61 -> A192 -> A174 ->
# Support: 0.058
# Confidence: 0.6041666666666666
# Lift: 2.1124708624708624
# =====================================
# Rule: A201 -> 1 -> 4 -> A192 -> A174 -> A93 ->
# Support: 0.061
# Confidence: 0.648936170212766
# Lift: 2.2690075881565246
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> A143 -> A153 ->
# Support: 0.068
# Confidence: 0.6296296296296297
# Lift: 6.296296296296296
# =====================================
# Rule: A101 -> A124 -> 1 -> A143 -> A153 -> A93 ->
# Support: 0.053
# Confidence: 0.646341463414634
# Lift: 6.732723577235771
# =====================================
# Rule: A101 -> A173 -> A201 -> A124 -> 1 -> A153 ->
# Support: 0.052
# Confidence: 0.6046511627906977
# Lift: 6.432459178624444
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> A192 -> A153 ->
# Support: 0.055
# Confidence: 0.632183908045977
# Lift: 6.725360723893372
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> A61 -> A153 ->
# Support: 0.056
# Confidence: 0.6222222222222222
# Lift: 6.619385342789598
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> A153 -> A93 ->
# Support: 0.072
# Confidence: 0.6666666666666666
# Lift: 7.092198581560283
# =====================================
# Rule: A101 -> 1 -> A174 -> A192 -> A143 -> A152 ->
# Support: 0.058
# Confidence: 0.6170212765957447
# Lift: 2.0164094006396884
# =====================================
# Rule: A101 -> A201 -> 1 -> A192 -> A174 -> A143 ->
# Support: 0.092
# Confidence: 0.6216216216216216
# Lift: 2.058349740468946
# =====================================
# Rule: A101 -> 1 -> A192 -> A174 -> A143 -> A32 ->
# Support: 0.052
# Confidence: 0.7027027027027027
# Lift: 2.2964140611199437
# =====================================
# Rule: A101 -> 1 -> A61 -> A192 -> A174 -> A143 ->
# Support: 0.061
# Confidence: 0.6354166666666666
# Lift: 2.076525054466231
# =====================================
# Rule: A101 -> 1 -> A192 -> A174 -> A143 -> A93 ->
# Support: 0.059
# Confidence: 0.6276595744680851
# Lift: 2.0511750799610624
# =====================================
# Rule: A101 -> A201 -> 1 -> A151 -> A92 -> A191 ->
# Support: 0.058
# Confidence: 0.6236559139784946
# Lift: 2.01179327089837
# =====================================
# Rule: A101 -> A201 -> 1 -> A192 -> A174 -> A152 ->
# Support: 0.071
# Confidence: 0.7553191489361701
# Lift: 2.0524976873265492
# =====================================
# Rule: A101 -> A201 -> 1 -> A192 -> A174 -> A32 ->
# Support: 0.058
# Confidence: 0.7837837837837839
# Lift: 2.129847238542891
# =====================================
# Rule: A101 -> A201 -> 1 -> A61 -> A192 -> A174 ->
# Support: 0.074
# Confidence: 0.7708333333333333
# Lift: 2.0946557971014492
# =====================================
# Rule: A101 -> A201 -> 1 -> A192 -> A174 -> A93 ->
# Support: 0.076
# Confidence: 0.8085106382978723
# Lift: 2.1970397779833486
# =====================================
# Rule: A201 -> A124 -> 1 -> A143 -> A153 -> A93 ->
# Support: 0.054
# Confidence: 0.6585365853658536
# Lift: 6.456241032998565
# =====================================
# Rule: A201 -> 1 -> A14 -> A43 -> A143 -> A34 ->
# Support: 0.051
# Confidence: 0.6375
# Lift: 2.017405063291139
# =====================================
# Rule: A201 -> 1 -> A192 -> A174 -> A143 -> A152 ->
# Support: 0.058
# Confidence: 0.8285714285714285
# Lift: 2.0976491862567808
# =====================================
# Rule: A201 -> 1 -> A192 -> A174 -> A143 -> A32 ->
# Support: 0.052
# Confidence: 0.7027027027027027
# Lift: 2.2028297890366857
# =====================================
# Rule: A201 -> 1 -> A61 -> A192 -> A174 -> A143 ->
# Support: 0.061
# Confidence: 0.648936170212766
# Lift: 2.0279255319148937
# =====================================
# Rule: A201 -> 1 -> A192 -> A174 -> A143 -> A93 ->
# Support: 0.061
# Confidence: 0.648936170212766
# Lift: 2.03428266524378
# =====================================
# Rule: A201 -> 1 -> A192 -> A174 -> A93 -> A152 ->
# Support: 0.05
# Confidence: 0.8474576271186441
# Lift: 2.145462347135808
# =====================================
# Rule: A201 -> 1 -> A61 -> A192 -> A174 -> A93 ->
# Support: 0.05
# Confidence: 0.8771929824561404
# Lift: 2.2207417277370642
# =====================================
# Rule: A101 -> A124 -> 4 -> 2 -> A143 -> A153 ->
# Support: 0.054
# Confidence: 0.627906976744186
# Lift: 7.055134570159394
# =====================================
# Rule: A101 -> A201 -> A124 -> 4 -> 2 -> A153 ->
# Support: 0.073
# Confidence: 0.6759259259259259
# Lift: 7.19070133963751
# =====================================
# Rule: A101 -> A124 -> 4 -> 2 -> A153 -> A93 ->
# Support: 0.057
# Confidence: 0.6627906976744187
# Lift: 7.53171247357294
# =====================================
# Rule: A101 -> A201 -> 4 -> A92 -> 2 -> A151 ->
# Support: 0.052
# Confidence: 0.6265060240963854
# Lift: 2.0676766471827905
# =====================================
# Rule: A101 -> A201 -> 4 -> A192 -> 2 -> A174 ->
# Support: 0.064
# Confidence: 0.8
# Lift: 2.15633423180593
# =====================================
# Rule: A201 -> A124 -> 4 -> 2 -> A143 -> A153 ->
# Support: 0.055
# Confidence: 0.6395348837209303
# Lift: 6.593143131143611
# =====================================
# Rule: A201 -> A124 -> 4 -> 2 -> A153 -> A93 ->
# Support: 0.057
# Confidence: 0.6627906976744187
# Lift: 7.050964868876794
# =====================================
# Rule: A101 -> A201 -> A124 -> 2 -> A143 -> A153 ->
# Support: 0.06
# Confidence: 0.6976744186046512
# Lift: 6.520321669202348
# =====================================
# Rule: A101 -> A201 -> A124 -> A61 -> 2 -> A153 ->
# Support: 0.053
# Confidence: 0.6162790697674418
# Lift: 7.515598411798071
# =====================================
# Rule: A101 -> A201 -> A124 -> 2 -> A153 -> A93 ->
# Support: 0.065
# Confidence: 0.6018518518518519
# Lift: 6.998277347114557
# =====================================
# Rule: A101 -> A201 -> A192 -> 2 -> A174 -> A143 ->
# Support: 0.067
# Confidence: 0.7976190476190477
# Lift: 2.1499165704017456
# =====================================
# Rule: A101 -> A201 -> A61 -> A192 -> 2 -> A174 ->
# Support: 0.059
# Confidence: 0.6145833333333333
# Lift: 2.119252873563218
# =====================================
# Rule: A101 -> A201 -> A192 -> 2 -> A174 -> A93 ->
# Support: 0.063
# Confidence: 0.6702127659574468
# Lift: 2.311078503301541
# =====================================
# Rule: A101 -> A201 -> A124 -> 4 -> A143 -> A153 ->
# Support: 0.068
# Confidence: 0.6296296296296297
# Lift: 7.074490220557637
# =====================================
# Rule: A101 -> A124 -> 4 -> A143 -> A153 -> A93 ->
# Support: 0.053
# Confidence: 0.646341463414634
# Lift: 7.344789356984478
# =====================================
# Rule: A101 -> A173 -> A201 -> A124 -> 4 -> A153 ->
# Support: 0.053
# Confidence: 0.6162790697674418
# Lift: 6.698685540950455
# =====================================
# Rule: A101 -> A201 -> A124 -> 4 -> A61 -> A153 ->
# Support: 0.055
# Confidence: 0.6111111111111112
# Lift: 6.642512077294687
# =====================================
# Rule: A101 -> A201 -> A124 -> 4 -> A153 -> A93 ->
# Support: 0.07
# Confidence: 0.6481481481481483
# Lift: 7.449978714346532
# =====================================
# Rule: A101 -> 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.068
# Confidence: 0.6181818181818183
# Lift: 2.0537601932950773
# =====================================
# Rule: A101 -> 4 -> A14 -> A75 -> A93 -> A152 ->
# Support: 0.064
# Confidence: 0.7272727272727273
# Lift: 2.0602626834921454
# =====================================
# Rule: A101 -> A173 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.055
# Confidence: 0.7333333333333334
# Lift: 2.0774315391879132
# =====================================
# Rule: A101 -> A201 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.081
# Confidence: 0.7043478260869566
# Lift: 2.047522750252781
# =====================================
# Rule: A101 -> A201 -> 4 -> A192 -> A174 -> A143 ->
# Support: 0.069
# Confidence: 0.6448598130841122
# Lift: 2.1352973943182523
# =====================================
# Rule: A101 -> A72 -> A201 -> 4 -> A92 -> A143 ->
# Support: 0.051
# Confidence: 0.621951219512195
# Lift: 2.0062942564909516
# =====================================
# Rule: A101 -> 4 -> A93 -> A75 -> A143 -> A34 ->
# Support: 0.06
# Confidence: 0.631578947368421
# Lift: 2.098268928134289
# =====================================
# Rule: A101 -> A201 -> 4 -> A92 -> A151 -> A32 ->
# Support: 0.051
# Confidence: 0.6071428571428571
# Lift: 2.1839671120246655
# =====================================
# Rule: A101 -> A201 -> 4 -> A192 -> A174 -> A152 ->
# Support: 0.05
# Confidence: 0.8064516129032259
# Lift: 2.1737240239979134
# =====================================
# Rule: A101 -> A201 -> 4 -> A61 -> A192 -> A174 ->
# Support: 0.056
# Confidence: 0.8235294117647058
# Lift: 2.2197558268590454
# =====================================
# Rule: A101 -> A201 -> 4 -> A192 -> A174 -> A93 ->
# Support: 0.058
# Confidence: 0.6170212765957447
# Lift: 2.3109411108454854
# =====================================
# Rule: A201 -> A124 -> 4 -> A143 -> A153 -> A93 ->
# Support: 0.054
# Confidence: 0.6585365853658536
# Lift: 7.005708354955889
# =====================================
# Rule: 4 -> A14 -> A75 -> A143 -> A93 -> A152 ->
# Support: 0.056
# Confidence: 0.6363636363636365
# Lift: 2.1141649048625797
# =====================================
# Rule: A173 -> 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.05
# Confidence: 0.6666666666666667
# Lift: 2.21483942414175
# =====================================
# Rule: A201 -> 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.069
# Confidence: 0.6
# Lift: 2.0761245674740487
# =====================================
# Rule: A201 -> 4 -> A14 -> A75 -> A93 -> A152 ->
# Support: 0.065
# Confidence: 0.7386363636363638
# Lift: 2.001724562700173
# =====================================
# Rule: A173 -> A201 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.057
# Confidence: 0.76
# Lift: 2.059620596205962
# =====================================
# Rule: A173 -> 4 -> A75 -> A143 -> A93 -> A191 ->
# Support: 0.059
# Confidence: 0.6413043478260869
# Lift: 2.130579228658096
# =====================================
# Rule: A201 -> 4 -> A93 -> A75 -> A143 -> A34 ->
# Support: 0.062
# Confidence: 0.6138613861386139
# Lift: 2.039406598467156
# =====================================
# Rule: A101 -> A201 -> A124 -> A143 -> A153 -> A93 ->
# Support: 0.059
# Confidence: 0.7195121951219512
# Lift: 6.918386491557223
# =====================================
# Rule: A101 -> A173 -> A201 -> A124 -> A153 -> A93 ->
# Support: 0.05
# Confidence: 0.7936507936507937
# Lift: 7.631257631257633
# =====================================
# Rule: A101 -> A201 -> A192 -> A174 -> A143 -> A152 ->
# Support: 0.057
# Confidence: 0.6063829787234043
# Lift: 2.0078906580245177
# =====================================
# Rule: A101 -> A201 -> A192 -> A174 -> A143 -> A32 ->
# Support: 0.051
# Confidence: 0.6891891891891891
# Lift: 2.282083407911222
# =====================================
# Rule: A101 -> A201 -> A61 -> A192 -> A174 -> A143 ->
# Support: 0.06
# Confidence: 0.625
# Lift: 2.06953642384106
# =====================================
# Rule: A101 -> A201 -> A192 -> A174 -> A143 -> A93 ->
# Support: 0.059
# Confidence: 0.6276595744680851
# Lift: 2.0783429618148515
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> 4 -> 2 -> A153 ->
# Support: 0.065
# Confidence: 0.6018518518518519
# Lift: 7.251227130745203
# =====================================
# Rule: A101 -> A124 -> 1 -> 4 -> 2 -> A153 -> A93 ->
# Support: 0.05
# Confidence: 0.6493506493506493
# Lift: 7.378984651711924
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A92 -> 2 -> A151 ->
# Support: 0.052
# Confidence: 0.6265060240963854
# Lift: 2.074523258597303
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A174 -> 2 -> A192 ->
# Support: 0.063
# Confidence: 0.7875
# Lift: 2.139945652173913
# =====================================
# Rule: A201 -> A124 -> 1 -> 4 -> 2 -> A153 -> A93 ->
# Support: 0.05
# Confidence: 0.6493506493506493
# Lift: 6.907985631389886
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> 2 -> A143 -> A153 ->
# Support: 0.053
# Confidence: 0.6162790697674418
# Lift: 6.162790697674418
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> 2 -> A153 -> A93 ->
# Support: 0.058
# Confidence: 0.6744186046511629
# Lift: 7.174666006927264
# =====================================
# Rule: A101 -> A201 -> 1 -> A174 -> 2 -> A192 -> A143 ->
# Support: 0.067
# Confidence: 0.6036036036036037
# Lift: 2.0813917365641506
# =====================================
# Rule: A101 -> A201 -> 1 -> A61 -> A192 -> 2 -> A174 ->
# Support: 0.058
# Confidence: 0.6041666666666666
# Lift: 2.105110336817654
# =====================================
# Rule: A101 -> A201 -> 1 -> A192 -> 2 -> A174 -> A93 ->
# Support: 0.062
# Confidence: 0.6595744680851063
# Lift: 2.2981688783453182
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> 4 -> A143 -> A153 ->
# Support: 0.061
# Confidence: 0.6161616161616161
# Lift: 6.923164226535013
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> 4 -> A153 -> A93 ->
# Support: 0.063
# Confidence: 0.6363636363636364
# Lift: 7.3145245559038665
# =====================================
# Rule: A101 -> 1 -> 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.066
# Confidence: 0.6
# Lift: 2.061855670103093
# =====================================
# Rule: A101 -> 1 -> 4 -> A14 -> A75 -> A93 -> A152 ->
# Support: 0.062
# Confidence: 0.7045454545454546
# Lift: 2.0844540075309306
# =====================================
# Rule: A101 -> A173 -> 1 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.054
# Confidence: 0.72
# Lift: 2.130177514792899
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.078
# Confidence: 0.6782608695652174
# Lift: 2.0615831901678336
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A174 -> A192 -> A143 ->
# Support: 0.069
# Confidence: 0.6448598130841122
# Lift: 2.1352973943182523
# =====================================
# Rule: A101 -> A72 -> A201 -> 1 -> 4 -> A92 -> A143 ->
# Support: 0.051
# Confidence: 0.621951219512195
# Lift: 2.0127871181624433
# =====================================
# Rule: A101 -> 1 -> 4 -> A93 -> A75 -> A143 -> A34 ->
# Support: 0.059
# Confidence: 0.6210526315789473
# Lift: 2.134201483089166
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A92 -> A151 -> A32 ->
# Support: 0.051
# Confidence: 0.6071428571428571
# Lift: 2.1918514698298086
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A61 -> A192 -> A174 ->
# Support: 0.055
# Confidence: 0.8088235294117646
# Lift: 2.197890025575447
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A192 -> A174 -> A93 ->
# Support: 0.057
# Confidence: 0.6063829787234043
# Lift: 2.288237655560016
# =====================================
# Rule: 1 -> 4 -> A14 -> A75 -> A143 -> A93 -> A152 ->
# Support: 0.055
# Confidence: 0.625
# Lift: 2.147766323024055
# =====================================
# Rule: A201 -> 1 -> 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.067
# Confidence: 0.7127659574468086
# Lift: 2.013463156629403
# =====================================
# Rule: A201 -> 1 -> 4 -> A14 -> A75 -> A93 -> A152 ->
# Support: 0.063
# Confidence: 0.7159090909090909
# Lift: 2.0223420647149464
# =====================================
# Rule: A173 -> A201 -> 1 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.056
# Confidence: 0.7466666666666667
# Lift: 2.1092278719397366
# =====================================
# Rule: 1 -> 4 -> A75 -> A143 -> A93 -> A191 -> A152 ->
# Support: 0.053
# Confidence: 0.7361111111111112
# Lift: 2.00030193236715
# =====================================
# Rule: A173 -> 1 -> 4 -> A75 -> A143 -> A93 -> A191 ->
# Support: 0.055
# Confidence: 0.632183908045977
# Lift: 2.100278764272349
# =====================================
# Rule: A201 -> 1 -> 4 -> A93 -> A75 -> A143 -> A34 ->
# Support: 0.061
# Confidence: 0.6039603960396039
# Lift: 2.0754652784866114
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> A143 -> A153 -> A93 ->
# Support: 0.053
# Confidence: 0.646341463414634
# Lift: 6.875973015049299
# =====================================
# Rule: A101 -> A201 -> 1 -> A174 -> A192 -> A143 -> A152 ->
# Support: 0.057
# Confidence: 0.6063829787234043
# Lift: 2.0078906580245177
# =====================================
# Rule: A101 -> A201 -> 1 -> A192 -> A174 -> A143 -> A32 ->
# Support: 0.051
# Confidence: 0.6891891891891891
# Lift: 2.282083407911222
# =====================================
# Rule: A101 -> A201 -> 1 -> A61 -> A192 -> A174 -> A143 ->
# Support: 0.06
# Confidence: 0.625
# Lift: 2.06953642384106
# =====================================
# Rule: A101 -> A201 -> 1 -> A192 -> A174 -> A143 -> A93 ->
# Support: 0.059
# Confidence: 0.6276595744680851
# Lift: 2.0783429618148515
# =====================================
# Rule: A101 -> A201 -> A124 -> 4 -> 2 -> A143 -> A153 ->
# Support: 0.054
# Confidence: 0.627906976744186
# Lift: 7.055134570159394
# =====================================
# Rule: A101 -> A201 -> A124 -> 4 -> 2 -> A153 -> A93 ->
# Support: 0.057
# Confidence: 0.6627906976744187
# Lift: 7.618283881315158
# =====================================
# Rule: A101 -> A201 -> A124 -> 4 -> A143 -> A153 -> A93 ->
# Support: 0.053
# Confidence: 0.646341463414634
# Lift: 7.429212223156714
# =====================================
# Rule: A101 -> 4 -> A14 -> A75 -> A143 -> A93 -> A152 ->
# Support: 0.053
# Confidence: 0.6022727272727273
# Lift: 2.1586836102965132
# =====================================
# Rule: A101 -> A201 -> 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.067
# Confidence: 0.6090909090909091
# Lift: 2.1075810003145645
# =====================================
# Rule: A101 -> A201 -> 4 -> A14 -> A75 -> A93 -> A152 ->
# Support: 0.063
# Confidence: 0.7159090909090909
# Lift: 2.081131078224102
# =====================================
# Rule: A101 -> A173 -> A201 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.055
# Confidence: 0.7333333333333334
# Lift: 2.1317829457364343
# =====================================
# Rule: A101 -> 4 -> A75 -> A143 -> A93 -> A191 -> A152 ->
# Support: 0.051
# Confidence: 0.7083333333333334
# Lift: 2.0066100094428707
# =====================================
# Rule: A101 -> A173 -> 4 -> A75 -> A143 -> A93 -> A191 ->
# Support: 0.055
# Confidence: 0.6470588235294117
# Lift: 2.1496970881375805
# =====================================
# Rule: A101 -> A201 -> 4 -> A93 -> A75 -> A143 -> A34 ->
# Support: 0.058
# Confidence: 0.6105263157894737
# Lift: 2.112547805499909
# =====================================
# Rule: A201 -> 4 -> A14 -> A75 -> A143 -> A93 -> A152 ->
# Support: 0.054
# Confidence: 0.6136363636363636
# Lift: 2.1233092167348224
# =====================================
# Rule: A173 -> A201 -> 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.05
# Confidence: 0.6666666666666667
# Lift: 2.3068050749711655
# =====================================
# Rule: A173 -> A201 -> 4 -> A75 -> A143 -> A93 -> A191 ->
# Support: 0.057
# Confidence: 0.6195652173913044
# Lift: 2.1438242816308115
# =====================================
# Rule: A101 -> A201 -> A124 -> 1 -> 4 -> 2 -> A153 -> A93 ->
# Support: 0.05
# Confidence: 0.6493506493506493
# Lift: 7.463800567248843
# =====================================
# Rule: A101 -> 1 -> 4 -> A14 -> A75 -> A143 -> A93 -> A152 ->
# Support: 0.052
# Confidence: 0.6046511627906977
# Lift: 2.167208468783863
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A14 -> A75 -> A143 -> A93 ->
# Support: 0.065
# Confidence: 0.6914893617021277
# Lift: 2.1017913729547955
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A14 -> A75 -> A93 -> A152 ->
# Support: 0.061
# Confidence: 0.6931818181818182
# Lift: 2.1069356175739156
# =====================================
# Rule: A101 -> A173 -> A201 -> 1 -> 4 -> A14 -> A75 -> A93 ->
# Support: 0.054
# Confidence: 0.72
# Lift: 2.188449848024316
# =====================================
# Rule: A101 -> 1 -> 4 -> A75 -> A143 -> A93 -> A191 -> A152 ->
# Support: 0.05
# Confidence: 0.6944444444444445
# Lift: 2.05456936226167
# =====================================
# Rule: A101 -> A173 -> 1 -> 4 -> A75 -> A143 -> A93 -> A191 ->
# Support: 0.051
# Confidence: 0.6375
# Lift: 2.117940199335548
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A93 -> A75 -> A143 -> A34 ->
# Support: 0.057
# Confidence: 0.6
# Lift: 2.150537634408602
# =====================================
# Rule: A201 -> 1 -> 4 -> A14 -> A75 -> A143 -> A93 -> A152 ->
# Support: 0.053
# Confidence: 0.6022727272727273
# Lift: 2.1586836102965132
# =====================================
# Rule: A173 -> A201 -> 1 -> 4 -> A75 -> A143 -> A93 -> A191 ->
# Support: 0.053
# Confidence: 0.6091954022988506
# Lift: 2.107942568508134
# =====================================
# Rule: A101 -> A201 -> 4 -> A14 -> A75 -> A143 -> A93 -> A152 ->
# Support: 0.052
# Confidence: 0.619047619047619
# Lift: 2.142033283901796
# =====================================
# Rule: A101 -> A173 -> A201 -> 4 -> A75 -> A143 -> A93 -> A191 ->
# Support: 0.054
# Confidence: 0.6352941176470588
# Lift: 2.1982495420313453
# =====================================
# Rule: A101 -> A201 -> 1 -> 4 -> A14 -> A75 -> A143 -> A93 -> A152 ->
# Support: 0.051
# Confidence: 0.6071428571428571
# Lift: 2.176139272913466
# =====================================
# Rule: A101 -> A173 -> A201 -> 1 -> 4 -> A75 -> A143 -> A93 -> A191 ->
# Support: 0.05
# Confidence: 0.625
# Lift: 2.162629757785467
# =====================================
